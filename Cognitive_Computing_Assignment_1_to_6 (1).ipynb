# %% [markdown]
# # Cognitive Computing — Assignment Solutions
#
# Simple Python solutions for all the given questions.

# %% [markdown]
# ## Assignment 1.1
# **WAP to print your name three times.**

# %%
name = input("Enter your name: ")

print(name)
print(name)
print(name)
# Out:
# Enter your name: Sumit Bansal
# Sumit Bansal
# Sumit Bansal
# Sumit Bansal

# %% [markdown]
# ## Assignment 2.1
# **WAP to add three numbers and print the result.**

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

result = a + b + c

print("Sum =", result)
# Out:
# Enter first number: 2
# Enter second number: 4
# Enter third number: 5
# Sum = 11

# %% [markdown]
# ## Assignment 2.2
# **WAP to concatenate three strings and print the result.**

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
str3 = input("Enter third string: ")

result = str1 + str2 + str3

print("Concatenated string =", result)
# Out:
# Enter first string: welcome
# Enter second string: to
# Enter third string: programming
# Concatenated string = welcometo programming

# %% [markdown]
# ## Assignment 4.1
# **WAP to print the table of 7 and 9.**

# %%
print("Table of 7")
for i in range(1, 11):
    print(7, "x", i, "=", 7 * i)

print("\nTable of 9")
for i in range(1, 11):
    print(9, "x", i, "=", 9 * i)
# Out:
# Table of 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# Table of 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# ## Assignment 4.2
# **WAP to print the table of n, where n is given by the user.**

# %%
n = int(input("Enter a number: "))

for i in range(1, 11):
    print(n, "x", i, "=", n * i)
# Out:
# Enter a number: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# ## Assignment 4.3
# **WAP to add all the numbers from 1 to n, where n is given by the user.**

# %%
n = int(input("Enter n: "))

total = 0

for i in range(1, n + 1):
    total = total + i

print("Sum =", total)
# Out:
# Enter n: 12
# Sum = 78

# %% [markdown]
# ## Assignment 5.1
# **WAP to find maximum among three numbers. Input is taken from the user. Try `max()` function.**

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

maximum = max(a, b, c)

print("Maximum number =", maximum)
# Out:
# Enter first number: 4
# Enter second number: 7
# Enter third number: 12
# Maximum number = 12

# %% [markdown]
# ## Assignment 5.2
# **WAP to add all numbers divisible by 7 and 9 from 1 to n, where n is given by the user.**

# %%
n = int(input("Enter n: "))

total = 0

for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        total = total + i

print("Sum =", total)
# Out:
# Enter n: 257
# Sum = 630

# %% [markdown]
# ## Assignment 5.3
# **WAP to add all prime numbers from 1 to n, where n is given by the user.**

# %%
n = int(input("Enter n: "))

total = 0

for num in range(2, n + 1):
    is_prime = True

    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break

    if is_prime:
        total = total + num

print("Sum of prime numbers =", total)
# Out:
# Enter n: 10
# Sum of prime numbers = 17

# %% [markdown]
# ## Assignment 6.1
# **WAP using a function that adds all odd numbers from 1 to n, where n is given by the user.**

# %%
def sum_odd_numbers(n):
    total = 0

    for i in range(1, n + 1):
        if i % 2 != 0:
            total = total + i

    return total


n = int(input("Enter n: "))

print("Sum of odd numbers =", sum_odd_numbers(n))
# Out:
# Enter n: 15
# Sum of odd numbers = 64

# %% [markdown]
# ## Assignment 6.2
# **WAP using a function that adds all prime numbers from 1 to n, where n is given by the user.**

# %%
def is_prime(num):
    if num < 2:
        return False

    for i in range(2, num):
        if num % i == 0:
            return False

    return True


def sum_prime_numbers(n):
    total = 0

    for i in range(1, n + 1):
        if is_prime(i):
            total = total + i

    return total


n = int(input("Enter n: "))

print("Sum of prime numbers =", sum_prime_numbers(n))
# Out:
# Enter n: 20
# Sum of prime numbers = 77
